# %% [markdown]
# # Marc, this is a python notebook with some of the data exploration; skip the following several lines until the next heading

# %%
import ATS_Analysis as ats
import pandas as pd
import numpy as np
import seaborn as sb

# %matplotlib inline
# Out:
# C:\Users\sottilep\AppData\Local\Continuum\Anaconda3\lib\site-packages\matplotlib\__init__.py:872: UserWarning: axes.color_cycle is deprecated and replaced with axes.prop_cycle; please use the latter.
#   warnings.warn(self.msg_depr % (key, alt_key))

# %%
patient_list = ['P100', 'P101', 'P102', 'P103', 'P104', 'P105', 'P106', 'P107', 'P108', 'P109', 'P110',
                'P112', 'P113', 'P114', 'P115', 'P116', 'P117','P118', 'P119', 'P120',
                'P121', 'P122', 'P124', 'P125', 'P127', 'P128', 'P129', 'P130' ]
#patient_list = ['P117']
df = ats.get_data(patient_list, [120])
# Out:
# Index(['analysis.ds', 'analysis.fl', 'analysis.ie', 'analysis.pl',
#        'analysis.pvt', 'patientID', 'vent_settings.FiO2', 'vent_settings.PEEP',
#        'vent_settings.p_mean'],
#       dtype='object')
# P100 30 16 4
# Index(['analysis.ds', 'analysis.fl', 'analysis.ie', 'analysis.pl',
#        'analysis.pvt', 'patientID', 'vent_settings.FiO2', 'vent_settings.PEEP',
#        'vent_settings.p_mean'],
#       dtype='object')
# P101 116 37 26
# Index(['analysis.ds', 'analysis.fl', 'analysis.ie', 'analysis.pl',
#        'analysis.pvt', 'patientID', 'vent_settings.FiO2', 'vent_settings.PEEP',
#        'vent_settings.p_mean'],
#       dtype='object')
# P102 49 1 0
# Index(['analysis.ds', 'analysis.fl', 'analysis.ie', 'analysis.pl',
#        'analysis.pvt', 'patientID', 'vent_settings.FiO2',
#        'vent_settings.p_mean'],
#       dtype='object')
# P103 28 16 14
# count    104.000000
# mean      -0.798077
# std        1.972529
# min       -6.000000
# 25%       -2.000000
# 50%       -0.500000
# 75%        0.000000
# max        4.000000
# Name: RASS, dtype: float64
# Index(['analysis.ds', 'analysis.fl', 'analysis.ie', 'analysis.pl',
#        'analysis.pvt', 'patientID'],
#       dtype='object')
# P104 104 0 0
# Index(['analysis.ds', 'analysis.fl', 'analysis.ie', 'analysis.pl',
#        'analysis.pvt', 'patientID', 'vent_settings.FiO2', 'vent_settings.PEEP',
#        'vent_settings.p_mean'],
#       dtype='object')
# P105 113 46 12
# Index(['analysis.ds', 'analysis.fl', 'analysis.ie', 'analysis.pl',
#        'analysis.pvt', 'patientID', 'vent_settings.FiO2', 'vent_settings.PEEP',
#        'vent_settings.p_mean'],
#       dtype='object')
# P106 30 15 15
# Index(['analysis.ds', 'analysis.fl', 'analysis.ie', 'analysis.pl',
#        'analysis.pvt', 'patientID', 'vent_settings.FiO2', 'vent_settings.PEEP',
#        'vent_settings.p_mean'],
#       dtype='object')
# P107 4 1 1
# Index(['analysis.ds', 'analysis.fl', 'analysis.ie', 'analysis.pl',
#        'analysis.pvt', 'patientID', 'vent_settings.FiO2', 'vent_settings.PEEP',
#        'vent_settings.p_mean'],
#       dtype='object')
# P108 27 1 1
# Index(['analysis.ds', 'analysis.fl', 'analysis.ie', 'analysis.pl',
#        'analysis.pvt', 'patientID', 'vent_settings.FiO2',
#        'vent_settings.p_mean'],
#       dtype='object')
# P109 33 6 6
# count    94.000000
# mean     -2.808511
# std       1.919210
# min      -6.000000
# 25%      -4.000000
# 50%      -3.000000
# 75%      -1.250000
# max       1.000000
# Name: RASS, dtype: float64
# Index(['analysis.ds', 'analysis.fl', 'analysis.ie', 'analysis.pl',
#        'analysis.pvt', 'patientID', 'vent_settings.FiO2', 'vent_settings.PEEP',
#        'vent_settings.p_mean'],
#       dtype='object')
# P110 94 33 28
# count    23.000000
# mean     -1.434783
# std       2.873485
# min      -6.000000
# 25%      -3.500000
# 50%       0.000000
# 75%       0.500000
# max       2.000000
# Name: RASS, dtype: float64
# Index(['analysis.ds', 'analysis.fl', 'analysis.ie', 'analysis.pl',
#        'analysis.pvt', 'patientID', 'vent_settings.FiO2', 'vent_settings.PEEP',
#        'vent_settings.p_mean'],
#       dtype='object')
# P112 23 7 7
# Index(['analysis.ds', 'analysis.fl', 'analysis.ie', 'analysis.pl',
#        'analysis.pvt', 'patientID', 'vent_settings.FiO2', 'vent_settings.PEEP',
#        'vent_settings.p_mean'],
#       dtype='object')
# P113 88 35 29
# Index(['analysis.ds', 'analysis.fl', 'analysis.ie', 'analysis.pl',
#        'analysis.pvt', 'patientID', 'vent_settings.FiO2', 'vent_settings.PEEP',
#        'vent_settings.p_mean'],
#       dtype='object')
# P114 51 13 13
# Index(['analysis.ds', 'analysis.fl', 'analysis.ie', 'analysis.pl',
#        'analysis.pvt', 'patientID', 'vent_settings.FiO2', 'vent_settings.PEEP',
#        'vent_settings.p_mean'],
#       dtype='object')
# P115 77 10 10
# count    8.000000
# mean    -5.500000
# std      1.069045
# min     -6.000000
# 25%     -6.000000
# 50%     -6.000000
# 75%     -5.750000
# max     -3.000000
# Name: RASS, dtype: float64
# Index(['analysis.ds', 'analysis.fl', 'analysis.ie', 'analysis.pl',
#        'analysis.pvt', 'patientID', 'vent_settings.FiO2', 'vent_settings.PEEP',
#        'vent_settings.p_mean'],
#       dtype='object')
# P116 8 5 5
# count    56.000000
# mean     -2.714286
# std       3.073135
# min      -6.000000
# 25%      -6.000000
# 50%      -3.000000
# 75%      -1.000000
# max       3.000000
# Name: RASS, dtype: float64
# Index(['analysis.ds', 'analysis.fl', 'analysis.ie', 'analysis.pl',
#        'analysis.pvt', 'patientID', 'vent_settings.FiO2',
#        'vent_settings.p_mean'],
#       dtype='object')
# P117 56 41 41
# count    43.000000
# mean     -2.139535
# std       2.641982
# min      -6.000000
# 25%      -5.000000
# 50%      -1.000000
# 75%       0.000000
# max       2.000000
# Name: RASS, dtype: float64
# Index(['analysis.ds', 'analysis.fl', 'analysis.ie', 'analysis.pl',
#        'analysis.pvt', 'patientID', 'vent_settings.FiO2', 'vent_settings.PEEP',
#        'vent_settings.p_mean'],
#       dtype='object')
# P118 43 13 9
# Index(['analysis.ds', 'analysis.fl', 'analysis.ie', 'analysis.pl',
#        'analysis.pvt', 'patientID', 'vent_settings.FiO2', 'vent_settings.PEEP',
#        'vent_settings.p_mean'],
#       dtype='object')
# P119 180 44 42
# count    17.000000
# mean     -3.647059
# std       1.617914
# min      -6.000000
# 25%      -4.000000
# 50%      -4.000000
# 75%      -4.000000
# max       1.000000
# Name: RASS, dtype: float64
# Index(['analysis.ds', 'analysis.fl', 'analysis.ie', 'analysis.pl',
#        'analysis.pvt', 'patientID', 'vent_settings.FiO2', 'vent_settings.PEEP',
#        'vent_settings.p_mean'],
#       dtype='object')
# P120 17 14 14
# Index(['analysis.ds', 'analysis.fl', 'analysis.ie', 'analysis.pl',
#        'analysis.pvt', 'patientID', 'vent_settings.FiO2',
#        'vent_settings.p_mean'],
#       dtype='object')
# P121 61 13 13
# count    129.000000
# mean      -1.906977
# std        2.431698
# min       -6.000000
# 25%       -4.000000
# 50%       -1.000000
# 75%        0.000000
# max        2.000000
# Name: RASS, dtype: float64
# Index(['analysis.ds', 'analysis.fl', 'analysis.ie', 'analysis.pl',
#        'analysis.pvt', 'patientID', 'vent_settings.FiO2', 'vent_settings.PEEP',
#        'vent_settings.p_mean'],
#       dtype='object')
# P122 129 59 56
# Index(['analysis.ds', 'analysis.fl', 'analysis.ie', 'analysis.pds',
#        'analysis.pl', 'analysis.pvt', 'patientID', 'vent_settings.FiO2',
#        'vent_settings.PEEP', 'vent_settings.p_mean'],
#       dtype='object')
# P124 108 21 21
# count    142.000000
# mean      -2.978873
# std        2.577778
# min       -6.000000
# 25%       -6.000000
# 50%       -3.000000
# 75%        0.000000
# max        2.000000
# Name: RASS, dtype: float64
# Index(['analysis.ds', 'analysis.fl', 'analysis.ie', 'analysis.pl',
#        'analysis.pvt', 'patientID', 'vent_settings.FiO2', 'vent_settings.PEEP',
#        'vent_settings.p_mean'],
#       dtype='object')
# P125 142 70 43
# Index(['analysis.ds', 'analysis.fl', 'analysis.ie', 'analysis.pds',
#        'analysis.pl', 'analysis.pvt', 'patientID', 'vent_settings.FiO2',
#        'vent_settings.p_mean'],
#       dtype='object')
# P127 76 2 2
# Index(['analysis.ds', 'analysis.fl', 'analysis.ie', 'analysis.pds',
#        'analysis.pl', 'analysis.pvt', 'patientID', 'vent_settings.FiO2',
#        'vent_settings.PEEP', 'vent_settings.p_mean'],
#       dtype='object')
# P128 2 1 1
# Index(['analysis.ds', 'analysis.fl', 'analysis.ie', 'analysis.pl',
#        'analysis.pvt', 'patientID', 'vent_settings.FiO2',
#        'vent_settings.p_mean'],
#       dtype='object')
# P129 88 78 76
# count    11.000000
# mean     -2.090909
# std       2.736953
# min      -6.000000
# 25%      -4.500000
# 50%       0.000000
# 75%       0.000000
# max       1.000000
# Name: RASS, dtype: float64
# Index(['analysis.ds', 'analysis.fl', 'analysis.ie', 'analysis.pds',
#        'analysis.pl', 'analysis.pvt', 'patientID', 'vent_settings.FiO2',
#        'vent_settings.PEEP', 'vent_settings.p_mean'],
#       dtype='object')
# P130 11 3 3

# %%
df.win.value_counts()
# Out:
# 120    492
# Name: win, dtype: int64

# %%
df = df[df.RASS <=0]

# %%
df.RASS.describe()
# Out:
# count    384.000000
# mean      -3.153646
# std        1.994729
# min       -6.000000
# 25%       -5.250000
# 50%       -3.000000
# 75%       -1.000000
# max        0.000000
# Name: RASS, dtype: float64

# %%
df.columns
# Out:
# Index(['RASS', 'SpO2', 'analysis.pds', 'ds_freq', 'ds_rolling',
#        'ds_tot_rolling', 'fio2_rolling', 'ie_freq', 'ie_rolling',
#        'ie_tot_rolling', 'p_mean_rolling', 'paCO2', 'paO2', 'patientID',
#        'peep_rolling', 'ph', 'pl_freq', 'pl_rolling', 'pl_tot_rolling', 'plat',
#        'pvt_freq', 'pvt_rolling', 'pvt_tot_rolling', 'vent_settings.FiO2',
#        'vent_settings.PEEP', 'vent_settings.p_mean', 'win'],
#       dtype='object')

# %%
grouped = df.groupby(['win'])
test = grouped.get_group(120)
test.head()
test.to_csv(u'c:\\Research_data\\RawData\\analysis.csv')

# %%
test = pd.read_csv(u'c:\\Research_data\\RawData\\analysis.csv')
test.columns
# Out:
# Index(['entry_time', 'RASS', 'SpO2', 'analysis.pds', 'ds_freq', 'ds_rolling',
#        'ds_tot_rolling', 'fio2_rolling', 'ie_freq', 'ie_rolling',
#        'ie_tot_rolling', 'p_mean_rolling', 'paCO2', 'paO2', 'patientID',
#        'peep_rolling', 'ph', 'pl_freq', 'pl_rolling', 'pl_tot_rolling', 'plat',
#        'pvt_freq', 'pvt_rolling', 'pvt_tot_rolling', 'vent_settings.FiO2',
#        'vent_settings.PEEP', 'vent_settings.p_mean', 'win'],
#       dtype='object')

# %%
sb.set_style('whitegrid')

# %% [markdown]
# # Ok, now this is where the data exploration starts
# ## Below are multiple scatter plots showing the bivariate relation of several things with an overlying linear regression line, data has been windowed for a 120min period around each RASS score
# #### -- ds_freq = frequency of double stacked breaths; for each type this is the number of dyssynchronous breaths over total breaths in a 120min period surround each RASS score
# #### -- ie_freq = frequency of ineffective triggers;
# #### -- pl_freq = frequency of flow limited breaths with dips in the pressure curve;
# #### -- RASS = RASS (these seemed to recored q4h);
# #### -- peep_rolling = average peep over 120min period;
# #### -- fio2_rolling = average fio2 over 120min period;
# #### -- p_mean_rolling = average mean airway pressure over 120min period;
# #### -- plat = plateau pressures as measured by RN, there are far fewer of these measurements;
# #### -- ph = pH for ABG, there are far fewer of these measurements
#
# ## Conclusions
# #### -- ds, ie, and flow limited breaths generally decrease with more negative RASS scores (-6 is NMB)
# #### -- fio2, peep, mean air way pressure don't have an obvious correlation with ds, pl
# #### -- fio2, peep, mean air way pressure may be inversely realted to ie, with less ie at higher fio2, peep, mean - this seems very wierd and is the opposite of what i would expect
# #### -- plat and ds, pl, ie may also be inversely related, again, this seems wierd
# #### -- i don't think there are enough ph data points to say anything meaningful
# #### -- as might be expected, more negative rass correlates with higher peep, plat, mean airway pressure, and fio2

# %%
sb.pairplot(test, y_vars=['ds_freq', 'pl_freq', 'pvt_freq', 'ie_freq', 'RASS'], 
            x_vars=['RASS', 'fio2_rolling', 'peep_rolling', 'p_mean_rolling', 'plat', 'ph', 'ds_freq', 'pl_freq', 'pvt_freq', 'ie_freq'],
            kind='reg')
# Out:
# C:\Users\sottilep\AppData\Local\Continuum\Anaconda3\lib\site-packages\matplotlib\__init__.py:892: UserWarning: axes.color_cycle is deprecated and replaced with axes.prop_cycle; please use the latter.
#   warnings.warn(self.msg_depr % (key, alt_key))

# %% [markdown]
# ## I then wanted to look more closely at the each type of dyssynchrony vs RASS score
# ### below is RASS vs ds breaths

# %%
sb.jointplot('RASS', 'ds_freq', data=test,  x_jitter=0.25, kind='reg', xlim=(-6.5, 0.5),  ylim=(-0.033,0.4)).set_axis_labels('RASS', 'Frequency of Double Triggered Breaths')
# Out:
# C:\Users\sottilep\AppData\Local\Continuum\Anaconda3\lib\site-packages\matplotlib\__init__.py:892: UserWarning: axes.color_cycle is deprecated and replaced with axes.prop_cycle; please use the latter.
#   warnings.warn(self.msg_depr % (key, alt_key))

# %% [markdown]
# ### below is then the histograms for the distribution of dyssynchrony frequency around each rass score

# %%
g = sb.FacetGrid(test, col='RASS', sharex=False, col_order=[-6, -5, -4, -3, -2, -1, 0], size=2, sharey=True, ylim=(-0.1,0.5))
g.map(sb.distplot, 'ds_freq', vertical=True)
# Out:
# C:\Users\sottilep\AppData\Local\Continuum\Anaconda3\lib\site-packages\matplotlib\__init__.py:892: UserWarning: axes.color_cycle is deprecated and replaced with axes.prop_cycle; please use the latter.
#   warnings.warn(self.msg_depr % (key, alt_key))

# %% [markdown]
# ## for flow limited breaths

# %%
sb.jointplot('RASS', 'pl_freq', data=test,  x_jitter=0.25, kind='reg', xlim=(-6.5, 0.5), ylim=(-0.1,1.2)).set_axis_labels('RASS', 'Frequency of Flow Limited Breaths')
# Out:
# C:\Users\sottilep\AppData\Local\Continuum\Anaconda3\lib\site-packages\matplotlib\__init__.py:892: UserWarning: axes.color_cycle is deprecated and replaced with axes.prop_cycle; please use the latter.
#   warnings.warn(self.msg_depr % (key, alt_key))

# %%
g = sb.FacetGrid(test, col='RASS', sharex=False, col_order=[-6, -5, -4, -3, -2, -1, 0], size=2, sharey=True, ylim=(-0.1,1.2))
g.map(sb.distplot, 'pl_freq', vertical=True)
# Out:
# C:\Users\sottilep\AppData\Local\Continuum\Anaconda3\lib\site-packages\matplotlib\__init__.py:892: UserWarning: axes.color_cycle is deprecated and replaced with axes.prop_cycle; please use the latter.
#   warnings.warn(self.msg_depr % (key, alt_key))

# %% [markdown]
# ## for pvt

# %%
sb.jointplot('RASS', 'pvt_freq', data=test,  x_jitter=0.25, kind='reg', xlim=(-6.5, 0.5), ylim=(-0.1,1.2)).set_axis_labels('RASS', 'Frequency of Premature Ventilator Termination Breaths')
# Out:
# C:\Users\sottilep\AppData\Local\Continuum\Anaconda3\lib\site-packages\matplotlib\__init__.py:892: UserWarning: axes.color_cycle is deprecated and replaced with axes.prop_cycle; please use the latter.
#   warnings.warn(self.msg_depr % (key, alt_key))

# %%
g = sb.FacetGrid(test, col='RASS', sharex=False, col_order=[-6, -5, -4, -3, -2, -1, 0], size=2, sharey=True, ylim=(-0.1,1.2))
g.map(sb.distplot, 'pvt_freq', vertical=True)
# Out:
# C:\Users\sottilep\AppData\Local\Continuum\Anaconda3\lib\site-packages\matplotlib\__init__.py:892: UserWarning: axes.color_cycle is deprecated and replaced with axes.prop_cycle; please use the latter.
#   warnings.warn(self.msg_depr % (key, alt_key))

# %% [markdown]
# ## for ineffective triggers

# %%
sb.jointplot('RASS', 'ie_freq', x_jitter=0.25, data=test, kind='reg', xlim=(-6.5, 0.5), ylim=(-0.1,1.2)).set_axis_labels('RASS', 'Frequency of Ineffective Triggered Breaths')
# Out:
# C:\Users\sottilep\AppData\Local\Continuum\Anaconda3\lib\site-packages\matplotlib\__init__.py:892: UserWarning: axes.color_cycle is deprecated and replaced with axes.prop_cycle; please use the latter.
#   warnings.warn(self.msg_depr % (key, alt_key))

# %%
g = sb.FacetGrid(test, col='RASS', sharex=False, col_order=[-6, -5, -4, -3, -2, -1, 0], size=2, sharey=True, ylim=(-0.1,1.2))
g.map(sb.distplot, 'ie_freq', vertical=True)
# Out:
# C:\Users\sottilep\AppData\Local\Continuum\Anaconda3\lib\site-packages\matplotlib\__init__.py:892: UserWarning: axes.color_cycle is deprecated and replaced with axes.prop_cycle; please use the latter.
#   warnings.warn(self.msg_depr % (key, alt_key))

# %% [markdown]
# ## Showing the same data another way:
# ### -- boxplots showing the distributions of dyssynchrony around each RASS measurement
# ## Conclusions:
# #### -- RASS of 4 has a wierd outlier for all types of dyssnchrony with an uptick in freuquency
# #### -- generally ds and fl breaths seem to be decreased below a RASS of 3;
# ### For DS breaths using JMP and paired wilcoxon tests
# #### -- RASS -6, -5, -3 are all signficantly lower than 0, -1, -2; all p<0.02
# #### -- RASS -4 is a has a couple of outliers that scews things

# %%
test.boxplot(column='ds_freq', by='RASS', layout=(6,1), figsize=(10,25))
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x000000001265CB70>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000000012775B00>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x00000000127C3390>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x00000000127FC080>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x00000000128428D0>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000000012881828>], dtype=object)

# %% [markdown]
# ## Conclusion for Pl breaths
# #### -- same general conclusions, generally decreased with RASS -3 and lower
# #### --  RASS -6, -5, -3 are all signficantly lower than 0, -1, -2; all p<0.005
# #### -- RASS -4 is a has a couple of outliers that scews things

# %%
test.boxplot(column='pl_freq', by='RASS', layout=(6,1), figsize=(10,25))
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x00000000128CDDD8>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x00000000129DCE10>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000000012A27E48>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000000012A68160>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000000012AAE9B0>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000000012AF14A8>], dtype=object)

# %%
## Conclusions for PVT Breaths

# %%
test.boxplot(column='pvt_freq', by='RASS', layout=(6,1), figsize=(10,25))
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x0000000012BD9128>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000000012C21048>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000000012C68860>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000000012CA2438>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000000012CEAA90>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000000012D2D898>], dtype=object)

# %% [markdown]
# # Conclusion for IE breaths
# #### -- same general conclusions, generally decreased with RASS -5 and lower
# #### --  RASS -6, -5, are all signficantly lower than 0, -1, -2, -3, -4; all p<0.005

# %%
test.boxplot(column='ie_freq', by='RASS', layout=(6,1), figsize=(10,25))
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x0000000012BA6E48>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000000012E4C240>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000000012E98278>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000000012ED0550>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000000012F17DA0>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000000012F5B898>], dtype=object)

# %% [markdown]
# ## Given this seeming cut off with a RASS of -3, I dicotomized RASS to <= -3 or >-3

# %%
def rass_tri(x):
    if x <=-5: return -2
    elif -5 < x <= -3: return -1
    else: return 0

test['rass_tri'] = test.RASS.apply(rass_tri)

test.boxplot(column=['ds_freq', 'pl_freq', 'pvt_freq', 'ie_freq'], by='rass_tri', layout=(1,4)),
# Out:
# (array([<matplotlib.axes._subplots.AxesSubplot object at 0x000000001306DB38>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000000130B2DD8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000000130FF4E0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000000013138240>], dtype=object),)

# %% [markdown]
# ## RASS as Binary

# %%
test['rass_binary'] = test.RASS.apply(lambda x: -1 if x <= -3 else 0)

test.boxplot(column=['ds_freq', 'pl_freq', 'pvt_freq', 'ie_freq'], by='rass_binary', layout=(1,4)),
# Out:
# (array([<matplotlib.axes._subplots.AxesSubplot object at 0x00000000132F66A0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000000001333D7F0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000000001338A588>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000000133C36A0>], dtype=object),)

# %% [markdown]
# ## Next, instead of looking at the freuency off dyssynchrony for each RASS, so that we could see distributions as above, i simple summed the total number of dyssynchonies for each RASS over total breas for each each RASS (ie, grouped all RASS -3 breaths together, summed and divided by total)
#
# #### -- the regression line for pl breaths is shockingly linear
# #### -- i am supprised by how poorly ds breaths are fit given the trend looked better above
# #### -- conversely, i am supporsed by how much cleaner the ie trend is this way given the way it looked above

# %%
grouped = test.groupby('RASS').sum()
grouped['ds_freq'] = grouped['ds_rolling'] / grouped['ds_tot_rolling']
grouped['pl_freq'] = grouped['pl_rolling'] / grouped['pl_tot_rolling']
grouped['ie_freq'] = grouped['ie_rolling'] / grouped['ie_tot_rolling']
grouped['pvt_freq'] = grouped['pvt_rolling'] / grouped['pvt_tot_rolling']
grouped.reset_index(inplace=True)

sb.jointplot('RASS','ds_freq', data=grouped, kind='reg', xlim=(-7,1))
sb.jointplot('RASS','pl_freq', data=grouped, kind='reg', xlim=(-7,1))
sb.jointplot('RASS','ie_freq', data=grouped, kind='reg', xlim=(-7,1))
sb.jointplot('RASS','pvt_freq', data=grouped, kind='reg', xlim=(-7,1))
# Out:
# C:\Users\sottilep\AppData\Local\Continuum\Anaconda3\lib\site-packages\matplotlib\__init__.py:892: UserWarning: axes.color_cycle is deprecated and replaced with axes.prop_cycle; please use the latter.
#   warnings.warn(self.msg_depr % (key, alt_key))

# %%
test.to_csv(u'c:\\Research_data\\RawData\\analysis.csv')

# %%
grouped
# Out:
#    RASS  SpO2  analysis.pds   ds_freq  ds_rolling  ds_tot_rolling  \
# 0    -6  7909           NaN  0.004603      1312.5          285153
# 1    -5  1078           NaN  0.004003       149.0           37220
# 2    -4  2931             1  0.050034      4317.5           86291
# 3    -3  4521           NaN  0.008982      1321.5          147135
# 4    -2  6139           NaN  0.034492      6637.0          192421
# 5    -1  6990           NaN  0.043929      8726.0          198640
# 6     0  1430           NaN  0.033335      1038.5           31153
#
#    fio2_rolling   ie_freq  ie_rolling  ie_tot_rolling  p_mean_rolling  paCO2  \
# 0   6512.155077  0.112627     32116.0          285153     1600.904530    714
# 1   1175.436624  0.080562      2998.5           37220      313.849991    230
# 2   1918.996588  0.290917     25103.5           86291      464.675421    138
# 3   2625.079412  0.178081     26202.0          147135      686.174987    581
# 4   3909.158826  0.244396     47027.0          192421      912.732932    354
# 5   4135.322377  0.317444     63057.0          198640      924.453043    162
# 6    824.973101  0.286730      8932.5           31153      165.726127     36
#
#    paO2  patientID  peep_rolling       ph   pl_freq    pl_rolling  \
# 0  1974      10646    936.861844  146.646  0.084206  24011.500000
# 1   676       2070    189.512604   44.215  0.084256   3136.000000
# 2   289       4093    264.506185   21.854  0.125691  10846.000000
# 3  1367       6455    287.000000  117.767  0.068573  10089.500000
# 4   815       7822    401.661440   73.175  0.187466  36072.333333
# 5   511       8994    511.190665   29.385  0.194540  38643.500000
# 6    67       1904     97.569853    7.513  0.295381   9202.000000
#
#    pl_tot_rolling  plat  pvt_freq   pvt_rolling  pvt_tot_rolling  \
# 0          285153   531  0.027301   7785.000000           285153
# 1           37220    55  0.064293   2393.000000            37220
# 2           86291   361  0.220788  19052.000000            86291
# 3          147135   411  0.052149   7673.000000           147135
# 4          192421   493  0.107656  20715.333333           192421
# 5          198640   426  0.159389  31661.000000           198640
# 6           31153    47  0.085658   2668.500000            31153
#
#    vent_settings.FiO2  vent_settings.PEEP  vent_settings.p_mean    win  \
# 0                3150                 460                   781  11520
# 1                 440                  59                   107   2040
# 2                 930                 128                   230   4080
# 3                 820                 101                   214   6960
# 4                1450                 147                   333   9360
# 5                1200                 151                   260  10080
# 6                 290                  28                    54   2040
#
#    rass_tri  rass_binary
# 0      -192          -96
# 1       -34          -17
# 2       -34          -34
# 3       -58          -58
# 4         0            0
# 5         0            0
# 6         0            0

# %% [markdown]
# ## Finally, I dropped my data into jump and did some linear regression to see with RASS as the predictor variable, ds, pl, or ie as the outcome; and fio2, peep, and mean airway pressure as covariates; I wanted to include plat pressures as well, but it dropped my n to form the mid 300s to the 70s; so I dropped it
#
# #### -- DS - RASS was the only signficnt predictors, covariates fell out (p<0.0001)
# #### -- PL - RASS indepedently associated (p<0.0001), everything else was also signficant as well
# #### -- IE - RASS independently associated (p<0.0001), as well as mean airway pressure and peep
# #### -- mean airway pressure correlated such that increased pressure was associated with less dyssynchrony when signficant (wierd); higher peeps correlated with more dyssynchrony (PL and IE)

# %% [markdown]
# ## As a sensitivity check, below shows how the median frequency of dyssynchrony is not really changed all that much (at least to an eye ball test) by changing the window measured around each RASS score
# ### -- 10 60, 120, and 240min intervals were tested
# ### -- I am somewhat suprised by this

# %%
#grouped = df.groupby(['win', 'RASS'])
#freq = grouped[['ds_rolling', 'pl_rolling', 'ie_rolling', 'ds_tot_rolling']].sum()
#freq.to_csv(u'c:\\Research_data\\RawData\\freq_analysis.csv')

# %%
#grouped[['ds_freq', 'pl_freq', 'ie_freq']].median().unstack(level=0)

# %%
#grouped[['ds_rolling', 'pl_rolling', 'ie_rolling', 'ds_tot_rolling']].sum().unstack(level=0)
